# %% [markdown]
# <a href="https://colab.research.google.com/github/NSNNNN/xgboost-ensemble-learning/blob/main/EnsembleLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Source
# The dataset used in this notebook is taken from:
# [Customer Churn Dataset on GitHub](https://github.com/RulerOfEternalNight/Customer-Churn-Prediction-Analysis-Using-Ensemble-Techniques)

# %%
# !pip install scikit-learn xgboost imbalanced-learn matplotlib seaborn

# %%
# !wget -O churn.csv "https://raw.githubusercontent.com/RulerOfEternalNight/Customer-Churn-Prediction-Analysis-Using-Ensemble-Techniques/main/dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv"
# Out:
# --2025-12-29 21:27:45--  https://raw.githubusercontent.com/RulerOfEternalNight/Customer-Churn-Prediction-Analysis-Using-Ensemble-Techniques/main/dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 970457 (948K) [text/plain]
# Saving to: ‘churn.csv’
#
# churn.csv           100%[===================>] 947.71K  --.-KB/s    in 0.03s
#
# 2025-12-29 21:27:45 (32.0 MB/s) - ‘churn.csv’ saved [970457/970457]

# %%
import pandas as pd

df = pd.read_csv('churn.csv')
df.head()  # نمایش چند ردیف اول دیتاست
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
from sklearn.model_selection import train_test_split

# فرض می‌کنیم ستون هدف 'Churn' است
X = df.drop('Churn', axis=1)
y = df['Churn']

# تبدیل ستون‌های متنی به عدد
X = pd.get_dummies(X)

# تقسیم داده‌ها
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, classification_report

# Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# Gradient Boosting
gb = GradientBoostingClassifier(random_state=42)
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)

# Voting Classifier (ترکیب دو مدل)
voting = VotingClassifier(estimators=[('rf', rf), ('gb', gb)], voting='hard')
voting.fit(X_train, y_train)
y_pred_vote = voting.predict(X_test)

# نمایش نتایج
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Gradient Boosting Accuracy:", accuracy_score(y_test, y_pred_gb))
print("Voting Classifier Accuracy:", accuracy_score(y_test, y_pred_vote))
# Out:
# Random Forest Accuracy: 0.7864849517319704
# Gradient Boosting Accuracy: 0.8023850085178875
# Voting Classifier Accuracy: 0.787052810902896
