# %% [markdown]
# <a href="https://colab.research.google.com/github/NSNNNN/xgboost-ensemble-learning/blob/main/Ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# نصب کتابخانه‌های مورد نیاز
# !pip install scikit-learn
# !pip install xgboost

# %%
from sklearn.datasets import load_iris

# بارگذاری دیتاست Iris
data = load_iris()
X = data.data
y = data.target

print("ویژگی‌ها:", X.shape)
print("تعداد کلاس‌ها:", len(set(y)))
# Out:
# ویژگی‌ها: (150, 4)
# تعداد کلاس‌ها: 3

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

print("تعداد نمونه‌های آموزش:", X_train.shape[0])
print("تعداد نمونه‌های تست:", X_test.shape[0])
# Out:
# تعداد نمونه‌های آموزش: 112
# تعداد نمونه‌های تست: 38

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=42)
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)

print("Gradient Boosting Accuracy:", accuracy_score(y_test, y_pred_gb))
print(classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
from sklearn.ensemble import VotingClassifier

voting = VotingClassifier(
    estimators=[('rf', rf), ('gb', gb)],
    voting='hard'
)
voting.fit(X_train, y_train)
y_pred_vote = voting.predict(X_test)

print("Voting Classifier Accuracy:", accuracy_score(y_test, y_pred_vote))
# Out:
# Voting Classifier Accuracy: 1.0
